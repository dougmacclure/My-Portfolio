# %%
#Load data into pandas and display information on variables

import pandas as pd

credit = pd.read_csv("creditcard.csv")

credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
#Look around the data, read the first 5 observations
credit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
#Check histogram for a particular variable
import matplotlib

credit.V1.plot()

# %%
#Create function which splits the data via random sampling

import numpy as np

def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data)*test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
#check histograms/distributions for each variable... only Time is bimodal, all other variables appear roughly normally distributed 
#unfortunately, we cannot determine outliers, since we are not given context for variables
#i.e., we cannot use business insights to ensure we have clean data

# %matplotlib inline
import matplotlib.pyplot as plt
credit.hist(bins=50, figsize=(25,15))
plt.show()

# %%
#are any of the independent variables correlated?

import matplotlib.pyplot as plt

plt.matshow(credit.corr())

# %%
#No.  Variables are uncorrelated

credit.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
#Create a function which randomly samples by id (will be created later).  To ensure the same test set is generated each time, we
#compute a hash of each instance's identifier, keep the last byte of the hash and put the instance in the test set if this value 
#is lower or equal to 51.
#So, the new test set will contain 20% of the new instances, but will not contain any instance previously in the training set.

import hashlib

def test_set_check(identifier, test_ratio, hash):
    return hash(np.int64(identifier)).digest()[-1] < 256*test_ratio

#random sampling

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
    ids = data[id_column]
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))
    return data.loc[~in_test_set], data[in_test_set]

# %%
#Split the data 70/30 for training/validation
credit_with_Primary_Key = credit.reset_index()
train_set, test_set = split_train_test_by_id(credit_with_Primary_Key, 0.3, "index")

# %%
#Prepare data for machine learning
fraud = train_set.drop("Class", axis=1)
fraud_labels = train_set["Class"].copy()

# %%
#Check distribution for dependent variable
credit.Class.plot()

# %%
#Prepare data for machine learning
fraud_clean = fraud.drop("index", axis=1)

# %%
#Verify we have independent variable data only
fraud_clean.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
#
#          V8        V9   ...         V20       V21       V22       V23  \
# 0  0.098698  0.363787   ...    0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425   ...   -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654   ...    0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024   ...   -0.208038 -0.108300  0.005274 -0.190321
# 6  0.081213  0.464960   ...   -0.219633 -0.167716 -0.270710 -0.154104
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
#Run logistic regression algo for binary classification

from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000, solver='lbfgs')
log_reg.fit(fraud_clean, fraud_labels)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Check first 5 observations of training data set to check model

some_data = fraud.iloc[:5]

# %%
some_labels = fraud_labels.iloc[:5]

# %%
some_clean_data = some_data.drop("index", axis=1)

# %%
print("Predictions:", log_reg.predict(some_clean_data))
# Out:
# Predictions: [0 0 0 0 0]

# %%
#So far so good.

print("Labels:", list(some_labels))
# Out:
# Labels: [0, 0, 0, 0, 0]

# %%
#Run the computed model on new data and determine model performance via confusion matrix and auc score

from sklearn.metrics import confusion_matrix

test_actual = test_set["Class"].copy()
test_clean1 = test_set.drop("Class", axis=1)
test_clean = test_clean1.drop("index", axis=1)

test_predicted = log_reg.predict(test_clean)
confusion_matrix(test_actual, test_predicted)
# Out:
# array([[85463,    19],
#        [   53,   107]], dtype=int64)

# %%
#Model mischaracterized 33% of fraudulent observations... could use some improvement

pd.value_counts(credit['Class'].values, sort=False)
# Out:
# 0    284315
# 1       492
# dtype: int64

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(test_actual, test_predicted)
# Out:
# 0.8342638654921504

# %%
#Decent AUC score and good accuracy score of 99.9%, however, the fraud rate is ~0.2%, which is unfortunate, since we have a 33% false negative rate.
#Next step(s): 1) try stratified sampling (to match fraud distribution) and then logistic regression
#              2) try random forest binary decision tree classification (relationship between independent variables and dependent variable likely non-linear) CAREFUL - THIS CAN LEAD TO OVERFITTING
#              3) try Amazon Machine Learning's Binary Classification Suite

# %%
#Split data via stratified sampling
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
for train_index, test_index in split.split(credit, credit["Class"]):
    strat_train_set = credit.loc[train_index]
    strat_test_set = credit.loc[test_index]

# %%
strat_fraud_clean = strat_train_set.drop("Class", axis=1)
strat_fraud_labels = strat_train_set["Class"].copy()

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000, solver='lbfgs')
log_reg.fit(strat_fraud_clean, strat_fraud_labels)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
strat_test_actual = strat_test_set["Class"].copy()
strat_test_clean = strat_test_set.drop("Class", axis=1)
strat_test_predicted = log_reg.predict(strat_test_clean)
confusion_matrix(strat_test_actual, strat_test_predicted)
# Out:
# array([[85276,    19],
#        [   62,    86]], dtype=int64)

# %%
#Stratified sampling wrt Class (!IsFraud) led to a poorer model.... move on!
#We should attempt to build a binary decision tree classification model
#If this doesn't work, attempt an ensemble model like random forest

# %%
from sklearn.tree import DecisionTreeClassifier

tree_binary = DecisionTreeClassifier()
tree_binary.fit(fraud_clean, fraud_labels)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
test_prediction = tree_binary.predict(test_clean)

# %%
confusion_matrix(test_actual, test_prediction)
# Out:
# array([[85450,    32],
#        [   37,   123]], dtype=int64)

# %%
#An improvement! Model mischaracterized 23% of fraudulent data.  Getting better... what about the stratified-split data set?  Do we get a greater improvement there?

# %%
from sklearn.tree import DecisionTreeClassifier

tree_binary = DecisionTreeClassifier()
tree_binary.fit(strat_fraud_clean, strat_fraud_labels)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
strat_test_actual = strat_test_set["Class"].copy()
strat_test_clean = strat_test_set.drop("Class", axis=1)
strat_test_predicted = tree_binary.predict(strat_test_clean)
confusion_matrix(strat_test_actual, strat_test_predicted)
# Out:
# array([[85262,    33],
#        [   42,   106]], dtype=int64)

# %%
#Not as good... try ensemble model e.g. random forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest_binary = RandomForestClassifier()
forest_binary.fit(fraud_clean, fraud_labels)
# Out:
# c:\users\dougm_000\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
test_prediction = forest_binary.predict(test_clean)

# %%
confusion_matrix(test_actual, test_prediction)
# Out:
# array([[85473,     9],
#        [   34,   126]], dtype=int64)

# %%
#A slight improvement... tweak some hyperparameters?

# %%
#Use entropy for split criterion instead of Gini index and increase n_estimators to 100
from sklearn.ensemble import RandomForestClassifier
forest_binary = RandomForestClassifier(n_estimators=100,criterion='entropy', max_depth=None, min_samples_split=2, 
                                       min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', 
                                       max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, 
                                       bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, 
                                       warm_start=False, class_weight=None)
forest_binary.fit(fraud_clean, fraud_labels)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
test_prediction = forest_binary.predict(test_clean)
confusion_matrix(test_actual, test_prediction)
# Out:
# array([[85474,     8],
#        [   30,   130]], dtype=int64)

# %%
#The model mischaracterized only 18.75% of fraudulent observations and had a , an acceptable model
#Check which independent variables had the highest incidence towards the target variable
print(forest_binary.feature_importances_)
# Out:
# [0.00782703 0.01040786 0.01118507 0.03737569 0.05369644 0.01334277
#  0.01103506 0.0320513  0.01047449 0.03017675 0.09752913 0.0797782
#  0.09549109 0.00850096 0.17672655 0.00797889 0.0568052  0.13410196
#  0.01766116 0.01032895 0.00954531 0.01436443 0.00799749 0.00724136
#  0.00628651 0.00688428 0.01489422 0.01066906 0.00920812 0.01043466]

# %%
#Retain tree description
forest_binary.decision_path(fraud_clean)
# Out:
# (<199165x25424 sparse matrix of type '<class 'numpy.int64'>'
#  	with 185956515 stored elements in Compressed Sparse Row format>,
#  array([    0,   271,   522,   735,   988,  1243,  1524,  1783,  2014,
#          2281,  2524,  2783,  3014,  3323,  3612,  3855,  4094,  4373,
#          4616,  4885,  5128,  5333,  5574,  5879,  6132,  6351,  6602,
#          6817,  7070,  7303,  7550,  7785,  8022,  8261,  8516,  8809,
#          9096,  9357,  9656,  9895, 10198, 10479, 10698, 10919, 11166,
#         11421, 11674, 11947, 12198, 12443, 12656, 12925, 13174, 13463,
#         13692, 13971, 14240, 14505, 14776, 15013, 15248, 15481, 15722,
#         15997, 16276, 16527, 16776, 17039, 17340, 17589, 17862, 18075,
#         18338, 18577, 18844, 19097, 19356, 19613, 19870, 20121, 20374,
#         20643, 20890, 21161, 21400, 21629, 21886, 22137, 22346, 22611,
#         22834, 23065, 23334, 23597, 23868, 24111, 24382, 24663, 24928,
#         25163, 25424], dtype=int32))
